# %%
import pandas as pd
import numpy as np
from sqlalchemy import create_engine 
import json

# %%
# df = pd.read_csv('./韩国政策_复制.csv')

# %%
json_data = ['{\n    "Service type": "Express",\n    "First service": "14 July 2012",\n    "Current operator(s)": "South Central Railway zone",\n    "Route": "Route",\n    "Termini": "Adilabad (ADB) Hazur Sahib Nanded (NED)",\n    "Stops": "7",\n    "Distance travelled": "184\\u00a0km (114\\u00a0mi)",\n    "Average journey time": "3 hours 52 minutes",\n    "Service frequency": "Daily",\n    "Train number(s)": "17409/17410",\n    "On-board services": "On-board services",\n    "Class(es)": "Second Class sitting, AC 3 Tier, Sleeper 3 Tier, Unreserved",\n    "Seating arrangements": "Yes",\n    "Sleeping arrangements": "Yes",\n    "Catering facilities": "No",\n    "Entertainment facilities": "No",\n    "Technical": "Technical",\n    "Rolling stock": "2",\n    "Track gauge": "1,676\\u00a0mm (5\\u00a0ft\\u00a06\\u00a0in)",\n    "Operating speed": "47\\u00a0km/h (29\\u00a0mph)"\n}', '{\n    "NaN": NaN,\n    "Agartala Tejas Rajdhani Express standing at Guwahati.": "Agartala Tejas Rajdhani Express standing at Guwahati.",\n    "Overview": "Overview",\n    "Service type": "Tejas Rajdhani Express",\n    "First service": "28\\u00a0October 2017; 7 years ago",\n    "Current operator(s)": "Northeast Frontier Railway",\n    "Route": "Route",\n    "Termini": "Agartala (AGTL) Anand Vihar Terminal (ANVT)",\n    "Stops": "15",\n    "Distance travelled": "2,423\\u00a0km (1,506\\u00a0mi)",\n    "Average journey time": "43hrs 40mins",\n    "Service frequency": "Weekly [a]",\n    "Train number(s)": "20501 / 20502",\n    "On-board services": "On-board services",\n    "Class(es)": "First AC, AC 2 tier, AC 3 tier.",\n    "Seating arrangements": "No",\n    "Sleeping arrangements": "Yes",\n    "Catering facilities": "Available",\n    "Observation facilities": "Large windows",\n    "Baggage facilities": "Below the seats",\n    "Technical": "Technical",\n    "Rolling stock": "LHB Tejas rakes",\n    "Track gauge": "1,676\\u00a0mm (5\\u00a0ft\\u00a06\\u00a0in)",\n    "Operating speed": "130\\u00a0km/h (81\\u00a0mph) maximum, 59\\u00a0km/h (37\\u00a0mph) average including halts.",\n    "Route map Legend Agartala Ambassa - Hojai Ambassa Dharmanagar  TripuraAssam border New Karimganj Jn Badarpur Junction Hojai Guwahati Rangiya - Barpeta Road Rangiya Junction Barpeta Road  AssamWest Bengal border New Jalpaiguri Junction Malda Town Bhagalpur - Jamalpur  West BengalBihar border Bhagalpur Junction Jamalpur Junction Patna Junction  BiharUttar Pradesh border Pandit Deen Dayal Upadhyaya Junction Kanpur Central  Uttar PradeshNew Delhi border Anand Vihar Terminal 20501 - Agartala \\u2192 Anand Vihar Terminal 20502 - Anand Vihar Terminal \\u2192 Agartala": "Route map Legend Agartala Ambassa - Hojai Ambassa Dharmanagar  TripuraAssam border New Karimganj Jn Badarpur Junction Hojai Guwahati Rangiya - Barpeta Road Rangiya Junction Barpeta Road  AssamWest Bengal border New Jalpaiguri Junction Malda Town Bhagalpur - Jamalpur  West BengalBihar border Bhagalpur Junction Jamalpur Junction Patna Junction  BiharUttar Pradesh border Pandit Deen Dayal Upadhyaya Junction Kanpur Central  Uttar PradeshNew Delhi border Anand Vihar Terminal 20501 - Agartala \\u2192 Anand Vihar Terminal 20502 - Anand Vihar Terminal \\u2192 Agartala",\n    "Route map": "Route map",\n    "Legend Agartala Ambassa - Hojai Ambassa Dharmanagar  TripuraAssam border New Karimganj Jn Badarpur Junction Hojai Guwahati Rangiya - Barpeta Road Rangiya Junction Barpeta Road  AssamWest Bengal border New Jalpaiguri Junction Malda Town Bhagalpur - Jamalpur  West BengalBihar border Bhagalpur Junction Jamalpur Junction Patna Junction  BiharUttar Pradesh border Pandit Deen Dayal Upadhyaya Junction Kanpur Central  Uttar PradeshNew Delhi border Anand Vihar Terminal 20501 - Agartala \\u2192 Anand Vihar Terminal 20502 - Anand Vihar Terminal \\u2192 Agartala": "Legend Agartala Ambassa - Hojai Ambassa Dharmanagar  TripuraAssam border New Karimganj Jn Badarpur Junction Hojai Guwahati Rangiya - Barpeta Road Rangiya Junction Barpeta Road  AssamWest Bengal border New Jalpaiguri Junction Malda Town Bhagalpur - Jamalpur  West BengalBihar border Bhagalpur Junction Jamalpur Junction Patna Junction  BiharUttar Pradesh border Pandit Deen Dayal Upadhyaya Junction Kanpur Central  Uttar PradeshNew Delhi border Anand Vihar Terminal 20501 - Agartala \\u2192 Anand Vihar Terminal 20502 - Anand Vihar Terminal \\u2192 Agartala",\n    "Legend": NaN,\n    "Agartala Ambassa - Hojai Ambassa Dharmanagar  TripuraAssam border New Karimganj Jn Badarpur Junction Hojai Guwahati Rangiya - Barpeta Road Rangiya Junction Barpeta Road  AssamWest Bengal border New Jalpaiguri Junction Malda Town Bhagalpur - Jamalpur  West BengalBihar border Bhagalpur Junction Jamalpur Junction Patna Junction  BiharUttar Pradesh border Pandit Deen Dayal Upadhyaya Junction Kanpur Central  Uttar PradeshNew Delhi border Anand Vihar Terminal": NaN,\n    "Ambassa - Hojai Ambassa Dharmanagar  TripuraAssam border New Karimganj Jn Badarpur Junction Hojai": "Ambassa - Hojai Ambassa Dharmanagar  TripuraAssam border New Karimganj Jn Badarpur Junction Hojai",\n    "Ambassa - Hojai": NaN,\n    "Ambassa": NaN,\n    "Tripura": NaN,\n    "Assam": NaN,\n    "Rangiya - Barpeta Road Rangiya Junction Barpeta Road  AssamWest Bengal border": "Rangiya - Barpeta Road Rangiya Junction Barpeta Road  AssamWest Bengal border",\n    "Rangiya - Barpeta Road": NaN,\n    "Rangiya Junction": NaN,\n    "West Bengal": NaN,\n    "Bhagalpur - Jamalpur  West BengalBihar border Bhagalpur Junction Jamalpur Junction": "Bhagalpur - Jamalpur  West BengalBihar border Bhagalpur Junction Jamalpur Junction",\n    "Bhagalpur - Jamalpur": NaN,\n    "West BengalBihar border": NaN,\n    "Bihar": NaN,\n    "Uttar Pradesh": NaN,\n    "New Delhi": NaN,\n    "20501 - Agartala \\u2192 Anand Vihar Terminal 20502 - Anand Vihar Terminal \\u2192 Agartala": NaN\n}', '{\n    "NaN": "This article needs additional citations for verification. Please help improve this article by adding citations to reliable sources. Unsourced material may be challenged and removed. Find sources:\\u00a0\\"Agnibina Express\\"\\u00a0\\u2013\\u00a0news\\u00a0\\u00b7 newspapers\\u00a0\\u00b7 books\\u00a0\\u00b7 scholar\\u00a0\\u00b7 JSTOR (August 2024) (Learn how and when to remove this message)"\n}', '{\n    "NaN": NaN,\n    "Overview": "Overview",\n    "Service type": "Superfast",\n    "Locale": "Madhya Pradesh, Maharashtra, Telangana, Andhra Pradesh, Tamil Nadu, Kerala",\n    "First service": "29\\u00a0October 1988; 36 years ago",\n    "Current operator(s)": "Southern Railway Zone",\n    "Route": "Route",\n    "Termini": "Indore Junction (INDB) Kochuveli (KCVL)",\n    "Stops": "48 as 22645 and 47 as 22646",\n    "Distance travelled": "2,645\\u00a0km (1,644\\u00a0mi)",\n    "Average journey time": "47 hours 5 minutes as 22645, 46 hours 30 minutes as 22646",\n    "Service frequency": "Weekly [a]",\n    "Train number(s)": "22645/22646",\n    "On-board services": "On-board services",\n    "Class(es)": "AC 2 Tier, AC 3 Tier, Ac Three tier Economy Class, Sleeper Class, General Unreserved",\n    "Seating arrangements": "Yes",\n    "Sleeping arrangements": "Yes",\n    "Catering facilities": "E-catering available at BPL, ET, BZU, NGP, CD, BPQ, WL, BZA, KPD, JTJ, SA, ED, TUP, CBE, PGT, TCR, AWR, ERS, QLN",\n    "Entertainment facilities": "No",\n    "Baggage facilities": "Below the seats",\n    "Technical": "Technical",\n    "Rolling stock": "ICF coaches",\n    "Track gauge": "1,676\\u00a0mm (5\\u00a0ft\\u00a06\\u00a0in)",\n    "Operating speed": "56\\u00a0km/h (35\\u00a0mph) average with halts for 22645, 57\\u00a0km/h (35\\u00a0mph) average with halts for 22646",\n    "Route map": "Route map"\n}']
data_dicts = [json.loads(item) for item in json_data]
# 直接转换为 DataFrame
# data_dicts
df = pd.DataFrame(data_dicts)
df
# 输出 DataFrame
# print(df)
# Out:
#              Service type                  First service  \
# 0                 Express                   14 July 2012
# 1  Tejas Rajdhani Express   28 October 2017; 7 years ago
# 2                     NaN                            NaN
# 3               Superfast  29 October 1988; 36 years ago
#
#           Current operator(s)  Route  \
# 0  South Central Railway zone  Route
# 1  Northeast Frontier Railway  Route
# 2                         NaN    NaN
# 3       Southern Railway Zone  Route
#
#                                        Termini                        Stops  \
# 0      Adilabad (ADB) Hazur Sahib Nanded (NED)                            7
# 1  Agartala (AGTL) Anand Vihar Terminal (ANVT)                           15
# 2                                          NaN                          NaN
# 3      Indore Junction (INDB) Kochuveli (KCVL)  48 as 22645 and 47 as 22646
#
#     Distance travelled                               Average journey time  \
# ...
