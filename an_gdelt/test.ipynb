# %%
import pandas as pd

# %%
df = pd.read_csv('./data/usa_festival_info.xlsx',sep='\t')

df2 = pd.read_csv('./data/20150219003000.mentions.CSV',sep='\t',skiprows=1)
# df3 = pd.read_csv("D:/项目文件/GKG.xlsx",sep='\t',skiprows=1)
df4 = pd.read_excel("D:/项目文件/GKG.xlsx")

# %%
df
# Out:
#       410446832  20140219  201402  2014  2014.1342 Unnamed: 5 Unnamed: 6  \
# 0     410446833  20140219  201402  2014  2014.1342        NaN        NaN
# 1     410446834  20140219  201402  2014  2014.1342        NaN        NaN
# 2     410446835  20140219  201402  2014  2014.1342        NaN        NaN
# 3     410446836  20140219  201402  2014  2014.1342        NaN        NaN
# 4     410446837  20140219  201402  2014  2014.1342        NaN        NaN
# ...         ...       ...     ...   ...        ...        ...        ...
# 3292  410450125  20150219  201502  2015  2015.1342     scoGOV   SCOTTISH
# 3293  410450126  20150219  201502  2015  2015.1342     scoGOV   SCOTTISH
# 3294  410450127  20150219  201502  2015  2015.1342     scoGOV   SCOTTISH
# 3295  410450128  20150219  201502  2015  2015.1342     scoGOV   SCOTTISH
# 3296  410450129  20150219  201502  2015  2015.1342        tam      TAMIL
#
#      Unnamed: 7 Unnamed: 8 Unnamed: 9  ... 1.4  \
# ...

# %%
df2
# Out:
#       410437215  20150219003000  20150219003000.1  1           buzzfeed.com  \
# 0     410437216  20150219003000    20150219003000  1           thehindu.com
# 1     410424156  20150219000000    20150219003000  1            stuff.co.nz
# 2     410424157  20150219000000    20150219003000  1            stuff.co.nz
# 3     410424210  20150219000000    20150219003000  1     thetimesherald.com
# 4     410437217  20150219003000    20150219003000  1           buzzfeed.com
# ...         ...             ...               ... ..                    ...
# 7985  410441012  20150219003000    20150219003000  1           thehindu.com
# 7986  410441013  20150219003000    20150219003000  1        theguardian.com
# 7987  410441014  20150219003000    20150219003000  1        theguardian.com
# 7988  410441015  20150219003000    20150219003000  1           scotsman.com
# 7989  410441016  20150219003000    20150219003000  1  scottishgreens.org.uk
#
# ...

# %%
df4
# Out:
#     Unnamed: 0                 DATE  SourceCollectionIdentifier  \
# 0  GKGRECORDID                  NaN                         NaN
# 1            1   20180322104500-239                2.018032e+13
# 2            2   20160718154500-505                2.016072e+13
# 3            3  20190508200000-1136                2.019051e+13
#
#    SourceCommonName DocumentIdentifier  \
# 0               NaN                NaN
# 1               1.0             aaj.tv
# 2               1.0             abc.az
# 3               1.0             al.com
#
#                                               Counts  V2Counts  Themes  \
# 0                                                NaN       NaN     NaN
# 1  http://aaj.tv/2018/03/kremlin-calls-johnson-li...       NaN     NaN
# 2                  http://abc.az/eng/news/97511.html       NaN     NaN
# 3                                 https://www.al.com       NaN     NaN
#
#                                             V2Themes  \
# ...
