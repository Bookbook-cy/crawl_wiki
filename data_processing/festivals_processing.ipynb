# %%
import pandas as pd

# %%
zj_df1 = pd.read_csv('../data/民俗民风/zongjiao.csv',encoding='utf-8')
zj_df2 = pd.read_csv('../data/民俗民风/zongjiao2.csv',encoding='utf-8')

# %%
zj_df = pd.concat([zj_df1,zj_df2])

# %%
dfc = pd.read_csv('../data/民俗民风/arts_and_clothing.csv',encoding='utf-8')

# %%
dfc
# Out:
#                                         ID  \
# 0     0c2f2c57-10ea-4605-b685-963fec9b8c7d
# 1     3907ddc6-0206-4570-b8a4-2fb0ea6dbbe3
# 2     240af35d-b2c9-4b77-b27d-ec4df5b05b55
# 3     4535178d-ab5f-43c6-ba3d-1738f2ee16fd
# 4     605ffded-8fd1-4607-af06-c3f09c5fb28a
# ...                                    ...
# 2120  ba3db9e7-1163-4a6f-852d-7a44e06dbb2b
# 2121  04527b6f-81ed-4d5f-b5f7-556dfcb0d6b4
# 2122  7ea810b1-4021-4624-b80a-33e53b4aefe2
# 2123  793649fd-e8ce-4b94-89e0-33a860f7d06f
# 2124  ce6afe0f-7bd2-4d16-bc74-32f99449ab80
#
#                                         name  \
# 0     All India Fine Arts and Crafts Society
# 1                                    Alkaluk
# 2                                      Agrun
# 3                        Accidentalism (art)
# 4                All India Handicrafts Board
# ...                                      ...
# 2120                                     貝珠衣
# 2121                                    風行字體
# ...

# %%
dfc.drop_duplicates(subset=['url'],inplace=True)

# %%
dfc
# Out:
#                                         ID  \
# 0     0c2f2c57-10ea-4605-b685-963fec9b8c7d
# 1     3907ddc6-0206-4570-b8a4-2fb0ea6dbbe3
# 2     240af35d-b2c9-4b77-b27d-ec4df5b05b55
# 3     4535178d-ab5f-43c6-ba3d-1738f2ee16fd
# 4     605ffded-8fd1-4607-af06-c3f09c5fb28a
# ...                                    ...
# 2118  f84c81de-4224-4a8e-9ea3-940145a6344a
# 2119  e28d6640-ecbf-4ec6-a4c4-748188880dce
# 2120  ba3db9e7-1163-4a6f-852d-7a44e06dbb2b
# 2122  7ea810b1-4021-4624-b80a-33e53b4aefe2
# 2124  ce6afe0f-7bd2-4d16-bc74-32f99449ab80
#
#                                         name  \
# 0     All India Fine Arts and Crafts Society
# 1                                    Alkaluk
# 2                                      Agrun
# 3                        Accidentalism (art)
# 4                All India Handicrafts Board
# ...                                      ...
# 2118                                      方衣
# 2119                                    風行字體
# ...

# %%
dfc.dropna(subset=['summary'],axis=0,inplace=True)

# %%
dfc.groupby('country').count()
# Out:
#           ID  name  url  title  summary  content  state  crawl_time
# country
# 印度       648   648  648    648      648      648      0         648
# 台湾         4     4    4      4        4        4      0           4
# 日本       946   946  946    946      946      946      0         946
# 美国       339   339  339    339      339      339      0         339
# 韩国        77    77   77     77       77       77      0          77

# %%
dfz = pd.read_csv('../data/民俗民风/zongjiao2.csv',encoding='utf-8')

# %%
dfz.groupby('country').count()
# Out:
#          ID  name  url  title  summary  content  state  crawl_time
# country
# 日本        7     7    7      7        7        7      0           7
# 韩国        5     5    5      5        5        5      0           5
